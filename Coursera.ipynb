# %%
print('helloworld you are the one who"s gonna conquer the world')
print('hello')
# Out:
# helloworld you are the one who"s gonna conquer the world
# hello

# %%
a = 'michael is a well known monkey'
b = a.replace('michael','artist')

# %%
b.find('well')
# Out:
# 12

# %%
b[11]
# Out:
# ' '

# %% [markdown]
# ## Operator Method

# %%
name = 'shahbaz'
print("he is %s who is the founder and CEO of MSB group" %(name))
# Out:
# he is shahbaz who is the founder and CEO of MSB group

# %% [markdown]
# # **Regular Expression**

# %%
import re

# %%
a = 'hello this is my bodygaurd'
sear = r'body' # r stands for raw text that python interpretor does not take anything in string for path changing command or any system command or escape sequence
result = re.search(sear,a)

# %%
if result :
    print("Find")

result.group()
# Out:
# Find
# 'body'

# %%
# \W this is used in re to match any non word character
pattern = r'\W'
string = 'Hello world!@'
res = re.findall(pattern , string)
if res:
    print("Found")
print("Matched String is --> " , res)
# Out:
# Found
# Matched String is -->  [' ', '!', '@']

# %%
s2 = "The BodyGuard is the best album of 'Whitney Houston'."
s2.split()[-6]
s2.split()
# Out:
# ['The',
#  'BodyGuard',
#  'is',
#  'the',
#  'best',
#  'album',
#  'of',
#  "'Whitney",
#  "Houston'."]

# %%
# sub is used for replacement of words in string
w = 'heroes'
rep = 'Whitney Houston'
resu = re.sub(rep , w , s2) # word to be replaced , word by which replaced , string in which to replace

# %%
resu
# Out:
# "The BodyGuard is the best album of 'heroes'."

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# "2"
#
# ```
#
# </details>

# %%
print(r"ab\nc") # r stands for raw string
# Out:
# ab
# c

# %%
int(False)
# Out:
# 0

# %%
int(True)
# Out:
# 1

# %%
str(1+1)
# Out:
# '2'

# %%
x = 1/1
print(type(x))
# Out:
# <class 'float'>

# %% [markdown]
# # Data Structure in Python

# %%
a = (1, 2.4 , 'mirza')
b = ('shahbaz' , True , 4.23)
c = a+b  # concatenation of two tuples

# %%
c[2][3]
# Out:
# 'z'

# %%
l = ['shahbaz' , 34 , True]
# del(l[0])
l.insert(2,3)  # it means insert 3 at index 2 so it dont overwrite instead it push the element present there to one index forward

# %%
l
# Out:
# ['shahbaz', 34, 3, True]

# %%
string = 'mirza shahbaz ali baig'
string.split(' ')
# Out:
# ['mirza', 'shahbaz', 'ali', 'baig']

# %%
help(list)
# Out:
# Help on class list in module builtins:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, index, /)
#  |      Return self[index].
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
# ...

# %%
a = [1]
a.extend([2,3,4,5])  # extend add elements indivually while append as it is

# %%
a
# Out:
# [1, 2, 3, 4, 5]

# %%
a = {1 : 'mirza' , 2 : 'shahbaz' , 3 : 'ali' , 4 : 'baig' , ('shahbaz') : 23}

# %%
for id , name in a.items():
    print(f'{id} --> {name}')
# Out:
# 1 --> mirza
# 2 --> shahbaz
# 3 --> ali
# 4 --> baig
# shahbaz --> 23

# %%
a.keys()
# Out:
# dict_keys([1, 2, 3, 4, 'shahbaz'])

# %%
a.values()
# Out:
# dict_values(['mirza', 'shahbaz', 'ali', 'baig'])

# %%
a.items()
# Out:
# dict_items([(1, 'mirza'), (2, 'shahbaz'), (3, 'ali'), (4, 'baig')])

# %%
d = {'a' : 1 , 'b' : 3}

# %%
print(type(d.keys()))
# Out:
# <class 'dict_keys'>

# %%
l = list(d) # so it change it to list including keys and values

# %%
l
# Out:
# ['a', 'b']

# %%
len(("disco",10,1.2, "hard rock",10))
# Out:
# 5

# %%
help(dict)
# Out:
# Help on class dict in module builtins:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
#  |  dict(**kwargs) -> new dictionary initialized with the name=value pairs
#  |      in the keyword argument list.  For example:  dict(one=1, two=2)
#  |
#  |  Methods defined here:
#  |
#  |  __contains__(self, key, /)
#  |      True if the dictionary has the specified key, else False.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
# ...

# %%
import re
st = 'he is 234 boy'
res = re.search(r'\d+' , st)
print(res.group())
# Out:
# 234

# %%
rt = 'this is, a;boy who!gonna'
parts = re.split(r"[;, ]" , rt)
print(parts)
# Out:
# ['this', 'is', '', 'a', 'boy', 'who!gonna']

# %%
a = [1]
a.extend([2,4,6])

# %%
a
# Out:
# [1, 2, 4, 6]

# %%
a.append([3,6,9])

# %%
del a[4]

# %%
a
# Out:
# [1, 2, 4, 6]

# %%
b = a.copy()

# %%
c = a

# %%
c.append([1,2,3])

# %%
a
# Out:
# [1, 2, 4, 6, [1, 2, 3]]

# %%
1=3
# Out:
#   Cell In[26], line 1
#     1=3
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
'a' == 'A'
# Out:
# False

# %%
l = range(2)

# %%
type(l)
# Out:
# range

# %% [markdown]
# ## **Difference Between sort and sorted**

# %%
l = [6,3,3,8,28,5]
g = sorted(l)

# %%
l
# Out:
# [6, 3, 3, 8, 28, 5]

# %%
g
# Out:
# [3, 3, 5, 6, 8, 28]

# %%
l.sort()

# %%
l
# Out:
# [3, 3, 5, 6, 8, 28]

# %%
g
# Out:
# [3, 3, 5, 6, 8, 28]

# %%
def take(*l): # for taking list as an argument
    for i in l:
        print(i)

# %%
l = [2,3,5,5,8,3]
take(l)
# Out:
# [2, 3, 5, 5, 8, 3]

# %%
def set_date():
    global date 
    date = 46
    print(date) # it is completely new thing for me
set_date()
print(date)
# Out:
# 46
# 46

# %%
set_date()
# Out:
# 46

# %%
date
# Out:
# 46

# %%
def greet(name):
    return "Hello, " + name
for _ in range(3):
    print(greet("Alice"))
# Out:
# Hello, Alice
# Hello, Alice
# Hello, Alice

# %%
g = 'hello i am gratefull to to to to have you here'
words = g.split()

# %%
words
# Out:
# ['hello',
#  'i',
#  'am',
#  'gratefull',
#  'to',
#  'to',
#  'to',
#  'to',
#  'have',
#  'you',
#  'here']

# %%
d = {}
for key in words:
    d[key] = words.count(key)

# %%
d
# Out:
# {'hello': 1,
#  'i': 1,
#  'am': 1,
#  'gratefull': 1,
#  'to': 4,
#  'have': 1,
#  'you': 1,
#  'here': 1}

# %%
def getBandRating(bandname):
    myFavouriteBand = "AC/DC"
    if bandname == myFavouriteBand:
        return 10.0
    else:
        return 0.0

print("AC/DC's rating is: ", getBandRating("AC/DC"))
print("Deep Purple's rating is: ", getBandRating("Deep Purple"))
# print("My favourite band is", myFavouriteBand)
# Out:
# AC/DC's rating is:  10.0
# Deep Purple's rating is:  0.0

# %%
len([sum([3,7])]) # most crucial mcqs
# Out:
# 1

# %%
try:
    a = 10 / 0
except ZeroDivisionError:
    print("You cant divide any number from zero")
# this add sophistication in error
# Out:
# You cant divide any number from zero

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 int('a')
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 a = 'hello' + 4
#
# TypeError: can only concatenate str (not "int") to str

# %%
a = 1

try:
    b = int(input("Please enter a number to divide a"))
    a = a/b
    print("Success a=",a)
except ZeroDivisionError:
    print("The number you provided cant divide 1 because it is 0")
except ValueError:
    print("You did not provide a number")
except:
    print("Something went wrong")
# Out:
# Success a= 0.3333333333333333

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# !pip install matplotlib
# Out:
# ^C
# ...
#   Using cached numpy-2.2.6-cp313-cp313-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached pillow-11.2.1-cp313-cp313-win_amd64.whl.metadata (9.1 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
# ...

# %%
dir(int)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
# ...

# %%
class Car:
    # Class attribute (shared by all instances)
    max_speed = 120  # Maximum speed in km/h
    # Constructor method (initialize instance attributes)
    def __init__(self, make, model, color, speed=0):
        self.make = make
        self.model = model
        self.color = color
        self.speed = speed  # Initial speed is set to 0
    # Method for accelerating the car
    def accelerate(self, acceleration):
        if self.speed + acceleration <= Car.max_speed:
            self.speed += acceleration
        else:
            self.speed = Car.max_speed # it is refering to Class name
    # Method to get the current speed of the car
    def get_speed(self):
        return self.speed

# %%
a = Car('Toyota' , 2019 , 'red')

# %%
a.accelerate(45)

# %%
a.get_speed()
# Out:
# 120

# %% [markdown]
# this is code <code> Hello World() </code>

# %%
d = {'a' : 1 , 'b' : 4}

# %% [markdown]
# ## **Vector Addition using strings**

# %%
a = [1,0]
b = [0,1]
c = []
for m , n in zip(a,b):
    c.append(m+n)

# %%
c
# Out:
# [1, 1]

# %%
print(4*a)
# Out:
# [1, 0, 1, 0, 1, 0, 1, 0]
